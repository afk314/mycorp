# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
# Load the file into pandas
jsonl = '/usr/local/tmp/out.jsonl'
df_orig = ''
with open(jsonl,"r") as json_file:
    data=json_file.read()
    df_orig = pd.read_json(data, lines=True)

# %%
df_orig.head(5)
# Out:
#    audience    categories        concepts  gender        id  max_age  min_age  \
# 0       3.0  [1040, 1030]         [20016]     0.0  aa100180     64.0     13.0
# 1       3.0        [1030]  [20058, 20044]     0.0  aa100355     64.0     13.0
# 2       3.0  [1018, 1030]            None     0.0  aa100367     64.0     13.0
# 3       3.0        [1021]  [21433, 22373]     2.0   aa10253    110.0      2.0
# 4       NaN           NaN             NaN     NaN  aa102542      NaN      NaN
#
#    setting                                               text
# 0      0.0  polyhydramnios  topic overview  polyhydramnios...
# 1      0.0  premature delivery in multiple pregnancy  topi...
# 2      0.0  multiple pregnancy: genetic disorders and birt...
# 3      0.0  ambulatory electrocardiogram  test overview  a...
# 4      NaN  hair growth  most scalp hair grows steadily. a...

# %%
# Get all of the unindexed documents
df_unindexed = df_orig[pd.isnull(df_orig['categories'])]

# %%
# Strip out any rows where concepts is null, NaN, ec
df_orig = df_orig[pd.notnull(df_orig['categories'])]

# %%
# Convert the numbers from float to int
df_orig['audience'] = df_orig['audience'].astype(int)
df_orig['max_age'] = df_orig['max_age'].astype(int)
df_orig['min_age'] = df_orig['min_age'].astype(int)
df_orig['gender'] = df_orig['gender'].astype(int)
df_orig['setting'] = df_orig['gender'].astype(int)

# %%
df_orig.head(5)
# Out:
#    audience    categories        concepts  gender        id  max_age  min_age  \
# 0         3  [1040, 1030]         [20016]       0  aa100180       64       13
# 1         3        [1030]  [20058, 20044]       0  aa100355       64       13
# 2         3  [1018, 1030]            None       0  aa100367       64       13
# 3         3        [1021]  [21433, 22373]       2   aa10253      110        2
# 6         3        [1034]            None       2  aa102618      110       19
#
#    setting                                               text
# 0        0  polyhydramnios  topic overview  polyhydramnios...
# 1        0  premature delivery in multiple pregnancy  topi...
# 2        0  multiple pregnancy: genetic disorders and birt...
# 3        2  ambulatory electrocardiogram  test overview  a...
# 6        2  hair loss caused by lack of protein  topic ove...

# %% [markdown]
# ### MultiLabelBinarizer
# Unless you can insure that your train dataset includes ALL LABELS, a hack needs to be introduced.  We will build out MultiLabelBinarizer off the complete set of concepts and use this object later against the train/test slices.  This will result in warnings, but unless we make certain all labels are present in train - its the only easy thing to do.

# %%
# Build our binary map array for the whole collection since we can't
# be certain that we don't use a label in the test set that isn't
# present in the train set
from sklearn import preprocessing
lb = preprocessing.MultiLabelBinarizer()
Y_all = lb.fit_transform(df_orig['categories'])
lb
# Out:
# MultiLabelBinarizer(classes=None, sparse_output=False)

# %%
ids = df_orig['id']

# %%
# Split into test/train
X_train, X_test, Y_train, Y_test, id_train, id_test = train_test_split(df_orig, Y_all, ids, test_size=0.3, random_state=1)

print("X Training set: ", len(X_train))
print("Y Training set: ", len(Y_train))
print("X Testing set: ", len(X_test))
print("Y Testing set: ", len(Y_test))
print("IDs Test: ", len(id_train))
print("IDs Train: ", len(id_test))
# Out:
# X Training set:  8151
# Y Training set:  8151
# X Testing set:  3494
# Y Testing set:  3494
# IDs Test:  8151
# IDs Train:  3494

# %%
#X_prime_train = X_train.drop('id',1).drop('categories',1).drop('concepts',1)
#Y_prime_train = Y_train
#X_prime_train

# %%
#X_prime_train.shape

# %%
#Y_prime_train.shape

# %%
X_train
# Out:
#        audience                            categories  \
# 13808         3                    [1032, 1040, 1049]
# 8554          3                    [1032, 1033, 1034]
# 8652          4  [1025, 1003, 1007, 1041, 1012, 1048]
# 12894         3                    [1040, 1020, 1030]
# 2730          3                                [1521]
# 2002          3                          [1531, 1516]
# 634           3                    [1032, 1040, 1030]
# 2335          3                                [1500]
# 2030          3                                [1505]
# 7585          0                                [1008]
# 15113         3                                [1005]
# 8498          0                                [1008]
# 8378          0                                [1008]
# 17355         0                          [1026, 1028]
# 364           3                    [1040, 1030, 1039]
# 446           3                          [1021, 1047]
# 17444         3                          [1505, 1517]
# 14143         3                          [1524, 1518]
# 16452         3                          [1516, 1519]
# 1606          2                          [1504, 1523]
# 15080         3                    [1024, 1034, 1018]
# 6344          3                          [1005, 1015]
# 10170         2                    [1005, 1006, 1007]
# 14381         3                          [1020, 1021]
# 9262          3                          [1004, 1029]
# 2206          3                          [1032, 1040]
# 857           2                          [1523, 1525]
# 9424          3                                [1011]
# 15087         0                          [1026, 1042]
# 781           3                          [1012, 1006]
# ...         ...                                   ...
# 1365          3                                [1021]
# 2211          0                          [1025, 1030]
# 15215         3                          [1524, 1502]
# 957           2                          [1010, 1007]
# 3481          3              [1024, 1028, 1005, 1023]
# 12907         2        [1025, 1036, 1038, 1007, 1020]
# 16426         3              [1512, 1504, 1533, 1518]
# 717           3                          [1026, 1045]
# 9386          3                                [1004]
# 12833         3                                [1004]
# 7428          0                                [1008]
# 4034          2                    [1504, 1523, 1533]
# 13678         2                          [1523, 1517]
# 2915          3                    [1016, 1020, 1021]
# 3386          1                          [1532, 1535]
# 8060          0                                [1008]
# 8082          0                                [1008]
# 14811         3                          [1521, 1533]
# 3934          3                    [1521, 1533, 1517]
# 16595         3                                [1521]
# 12227         3                                [1021]
# 6877          0                                [1008]
# 164           3                          [1020, 1028]
# 7728          0                                [1008]
# 3319          2                          [1523, 1515]
# 12307         2                    [1028, 1036, 1007]
# 16561         3                          [1521, 1524]
# 1123          3                          [1524, 1503]
# 7866          0                                [1008]
# 284           3                          [1020, 1038]
#
#                                   concepts  gender                id  max_age  \
# 13808           [23496, 5193, 5194, 21817]       0            tw3491       64
# 8554                               [20891]       2          hw103896      110
# 8652                               [20216]       2          hw119898      110
# 12894                               [4124]       0            tn9108       64
# 2730                                  None       2           abq6157      110
# 2002                               [20480]       2           abp2013      110
# 634                                [21478]       0           aa77493       64
# 2335                               [20431]       2           abq0133      110
# 2030                         [4209, 20446]       2           abp2722      110
# 7585                                  None       2        hn-1029002      110
# 15113                       [20369, 20370]       2            ug2980      110
# 8498                                  None       2        hn-4371007      110
# 8378                                  None       2        hn-3654008      110
# 17355                [22328, 21316, 20575]       2            zp3796      110
# 364                         [20056, 21782]       0           aa22092       64
# 446                                   None       2           aa46579      110
# 17444                              [21456]       2            zp4369      110
# 14143  [20417, 20418, 20003, 21814, 20823]       0            ud1160      110
# 16452                               [5142]       2            zc1559      110
# 1606                                  None       2           abo3261       18
# 15080                              [20107]       2            ug2799      110
# 6344                 [20249, 20250, 20251]       2             dizzi      110
# 10170                  [20784, 5142, 5143]       2  ncicdr0000257997       18
# 14381                  [22321, 4292, 4303]       2         ue4723abc      110
# 9262                               [20639]       2          hw209204      110
# 2206           [5063, 22270, 21814, 20823]       0           abp7160      110
# 857                                 [4578]       2           abk2216        1
# 9424                               [22239]       2          hw232128      110
# 15087                        [20425, 4542]       2            ug2865      110
# 781                                 [4570]       2           abj7482      110
# ...                                    ...     ...               ...      ...
# 1365                                [4190]       2           abn2035      110
# 2211                               [20046]       2           abp7186        1
# 15215                       [21944, 20135]       2            ug3883      110
# 957                                [22455]       2           abk6143       12
# 3481                        [20610, 23702]       2           acc7055      110
# 12907                              [22321]       2            tn9188       18
# 16426                       [21120, 20825]       2            zc1311      110
# 717                          [20113, 4700]       2          aae49333      110
# 9386                         [5041, 20604]       2          hw225143      110
# 12833                                 None       2            tn7444      110
# 7428                                  None       2       hn-10007437      110
# 4034                               [20876]       2            bz1061       18
# 13678           [5536, 4570, 23739, 23740]       2           tw12165       18
# 2915                         [20705, 4570]       2           abr5981      110
# 3386                         [4650, 22701]       2           abs2394      110
# 8060                                  None       2        hn-2113005      110
# 8082                                  None       2        hn-2135002      110
# 14811                              [20408]       2            uf8609      110
# 3934                         [4288, 20407]       2            bo1658      110
# 16595                               [5105]       2            zc2645      110
# 12227                              [20726]       2         te7167abc      110
# 6877                                  None       2       hn-10001021      110
# 164                  [22328, 22321, 21316]       2          aa131371      110
# 7728                                  None       2        hn-1216008      110
# 3319                               [20130]       2           abs1819       18
# 12307                                 None       2            te7868       18
# 16561         [20488, 20329, 20402, 22245]       2            zc2425      110
# 1123                        [22641, 22258]       2           abk9570      110
# 7866                                  None       2        hn-1395008      110
# 284                                [22321]       2          aa155258      110
#
#        min_age  setting                                               text
# 13808       13        0  abortion: emotional recovery  topic overview  ...
# 8554        13        2  laser surgery for genital warts  surgery overv...
# 8652         1        2  lead poisoning  topic overview  lead poisoning...
# 12894       13        0  pregnancy: vegetarian diet  topic overview  a ...
# 2730        19        2  weakness: care instructions weakness: generali...
# 2002         2        2  traumatic brain injury, long-term healing: car...
# 634         13        0  contraction stress test  test overview  a cont...
# 2335        13        2  latex allergy: care instructions latex allergy...
# 2030        19        2  learning about insulin pumps diabetes: insulin...
# 7585         0        2  high homocysteine (holistic)  about this condi...
# 15113       19        2  spinal cord injury: autonomic dysreflexia  top...
# 8498         0        2  type 1 diabetes (holistic)  about this conditi...
# 8378         0        2  buckthorn  uses  buckthorn is a tall shrub nat...
# 17355       19        2  breathing problems: how to control stress   st...
# 364         13        0  pregnancy: should i have an early fetal ultras...
# 446         50        2  isolated systolic high blood pressure  topic o...
# 17444       19        2  learning about body fat testing body fat testi...
# 14143       19        0  vaginal hysterectomy: what to expect at home h...
# 16452       19        2  malignant brain tumor (secondary): care instru...
# 1606         0        2  keratosis pilaris in children: care instructio...
# 15080       19        2  types of hair loss  topic overview  there are ...
# 6344         0        2  dizziness: lightheadedness and vertigo  topic ...
# 10170        0        2  childhood brain and spinal cord tumors treatme...
# 14381       45        2  modify recipes for a heart-healthy diet  topic...
# 9262        19        2  jaw problems: exercise and relaxation  topic o...
# 2206        19        0  hysterectomy for abnormal uterine bleeding: ho...
# 857          0        2  umbilical cord: care instructions umbilical co...
# 9424        19        2  liver biopsy  test overview  a liver biopsy is...
# 15087        2        2  inhaled corticosteroids for long-term control ...
# 781         13        2  lifestyle changes that may help prevent cancer...
# ...        ...      ...                                                ...
# 1365        19        2                how to put on compression stockings
# 2211         0        2  feeding your premature baby  your baby has bee...
# 15215       19        2  femoropopliteal bypass: what to expect at home...
# 957          2        2  diabetes, type 1: symptoms and treatment in ch...
# 3481        19        2  myalgic encephalomyelitis/chronic fatigue synd...
# 12907        0        2  healthy eating for children  topic overview  h...
# 16426        0        2  candidiasis: care instructions candidiasis  yo...
# 717         19        2  quitting smoking again  blank  in this interac...
# 9386        19        2  physical exam for tennis elbow  exam overview ...
# 12833       19        2  orthotics for foot problems  topic overview  o...
# 7428         0        2  omega-6 fatty acids  uses  omega-6 fatty acids...
# 4034         0        2  skin abscess in children: care instructions ab...
# 13678        2        2  a healthy lifestyle for your child: care instr...
# 2915        19        2  coronary artery disease: getting back on a hea...
# 3386        19        2  learning about how to use a bedpan caregiving:...
# 8060         0        2  huperzia  uses  huperzia is a type of moss tha...
# 8082         0        2  nettle  uses  nettle is a leafy plant that is ...
# 14811       19        2  hammer toe: care instructions hammer toe  your...
# 3934        13        2  mallet finger: exercises mallet finger | exerc...
# 16595       19        2  learning about total knee replacement surgery ...
# 12227       19        2  arrhythmias: foods that affect heart rate  top...
# 6877         0        2  daunorubicin liposome  drug information * magn...
# 164         19        2  eat a balanced diet for mental health  topic o...
# 7728         0        2  gallstones (holistic)  about this condition * ...
# 3319         0        2  nephrotic syndrome in children: care instructi...
# 12307        2        2  nonverbal learning disorder  topic overview  n...
# 16561       13        2  knee arthroscopy: before your surgery knee art...
# 1123        13        2  wisdom tooth extraction: what to expect at hom...
# 7866         0        2  glyburide  drug information  glyburide is a su...
# 284         19        2  hunger, fullness, and appetite signals  topic ...
#
# [8151 rows x 9 columns]

# %% [markdown]
# ```('vectorizer', CountVectorizer(lowercase=True,
#                                    stop_words='english',
#                                    max_df=0.8,
#                                    min_df=2)),
# ```
# 0.25254813137
#
# ```
# classifier = Pipeline([
# ('vectorizer', CountVectorizer(lowercase=True,
#                                    stop_words='english',
#                                    max_df=0.8,
#                                    min_df=4)),
#
# ```
#
# 0.249150622877

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(Y_train)
# Out:
# numpy.ndarray

# %%
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

from nltk.corpus import stopwords

classifier = Pipeline([
('vectorizer', CountVectorizer(lowercase=True, 
                                   stop_words=stopwords.words('english'), 
                                   max_df=0.8, 
                                   min_df=.01)),
('tfidf', TfidfTransformer()),   
('clf', OneVsRestClassifier(LinearSVC()))])

classifier.fit(X_train['text'], Y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.8, max_features=None, min_df=0.01,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=['...lti_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#           n_jobs=1))])

# %%
Y_predicted = classifier.predict(X_test['text'])
print("Test predictions: ",len(Y_predicted))
# Out:
# Test predictions:  3494

# %% [markdown]
# import numpy
# for count, prediction in enumerate(Y_predicted):
#     answer = Y_test[count]
#     print("Prediction length: ",len(prediction))
#     print("Answer length: ",len(answer))
#
#     print("--")
#     if np.array_equal(prediction, answer):
#         print("!")

# %%
from sklearn.metrics import accuracy_score
print(len(Y_test))
print(len(Y_predicted))
print("Accuracy Score: ",accuracy_score(Y_predicted, Y_test))

# %% [markdown]
# for id,concept in zip()

# %%
inversed = lb.inverse_transform(Y_predicted)
actual_inverse = lb.inverse_transform(Y_test)

# %%
for id, inverse, id, actual in zip(Y_predicted, inversed, id_test, actual_inverse):
    print('%r => %s | %s' % (id, inverse, actual))

#for doc, category in zip(docs_new, predicted):
#    print('%r => %s' % (doc, category))

# %%
def fix_hwcvs(ids):
    out = set()
    for i,a in enumerate(ids):
        str_a = a.astype(str)
        if len(str_a) == 4:
            str_a = str("0"+str(a))
        hwcv = 'cat'+str_a
        out.add(hwcv)
    return out

# %%
with open('/usr/local/tmp/categories.tsv', 'w') as f: 
    for id, inverse, id, actual in zip(Y_predicted, inversed, id_test, actual_inverse):
        predicted = fix_hwcvs(inverse)
        if (len(predicted) == 0):
            predicted = ""
        actual = fix_hwcvs(actual)
        
        predicted_s = str(predicted)
        actual_s = str(actual)
        
        x = id+'\t'+predicted_s+'\t'+str(actual_s)
        
        post = ""
        if len(predicted) == 0:
            post = "no prediction"
        elif predicted == actual:
            post = 'exact'
        elif predicted.issubset(actual):
            post = 'partial'
        else:
            post = 'wrong'
        out = str(x)+'\t'+post+'\n'
        f.write(out)
